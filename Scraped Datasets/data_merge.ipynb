# %%
import pandas as pd

# %%
df1 = pd.read_csv('Ahemdabad_Cleaned.csv')
df2 = pd.read_csv('Bangalore_Cleaned.csv')
df3 = pd.read_csv('Chandigarh_Cleaned.csv')
df4 = pd.read_csv('Chennai_Cleaned.csv')
df5 = pd.read_csv('Coimbatore_Cleaned.csv')
df6 = pd.read_csv('Delhi_Cleaned.csv')
df7 = pd.read_csv('Gurgaon_cleaned.csv')
df8 = pd.read_csv('Hyderabad_Cleaned.csv')
df9 = pd.read_csv('Jaipur_Cleaned.csv')
df10 = pd.read_csv('Kolkata_Cleaned.csv')
df11 = pd.read_csv('Lucknow_Cleaned.csv')
df12 = pd.read_csv('Mumbai_Cleaned.csv')
df13 = pd.read_csv('Nagpur_Cleaned.csv')
df14 = pd.read_csv('Noida_Cleaned.csv')
df15 = pd.read_csv('Patna_Cleaned.csv')
df16 = pd.read_csv('Pune_Cleaned.csv')
df17 = pd.read_csv('Surat_Cleaned.csv')
df18 = pd.read_csv('Vijayawada_Cleaned.csv')

# %%
df1.columns,df2.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'Area Type', 'State'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'Area Type', 'State'],
#        dtype='object'))

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df = df[['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
           'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
           'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
           'State', 'Area Type']]

# %%
df.columns, df3.columns, df4.columns, df5.columns, df6.columns, df7.columns, df8.columns, df9.columns, df10.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'Area Type', 'State'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
# ...

# %%
df = pd.concat([df, df3,df4,df5,df6,df7,df8,df9,df10], ignore_index=True)

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Karnatka', 'Chandigarh', 'Tamil Nadu', 'Delhi',
#        'Unknown', 'Telangana', 'Rajasthan', 'West Bengal'], dtype=object)

# %%
df.columns, df11.columns, df12.columns, df13.columns, df14.columns, df15.columns, df16.columns, df17.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type', 'Number of Bathrooms', 'Kids Play Areas'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
# ...

# %%
df = pd.concat([df, df11,df12,df13,df14,df15,df16,df17], ignore_index=True)

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Karnatka', 'Chandigarh', 'Tamil Nadu', 'Delhi',
#        'Unknown', 'Telangana', 'Rajasthan', 'West Bengal',
#        'Uttar Pradesh', 'Maharashtra', 'Bihar'], dtype=object)

# %%
df18.columns, df.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type', 'Number of Bathrooms', 'Kids Play Areas'],
#        dtype='object'))

# %%
df18 = df18.rename(columns={'Number of Bathrooms': 'Number of Bathroom'})

df18 = df18.rename(columns={'New Name': 'Kids Play Areas'})

# %%
df.columns , df18.columns
# Out:
# (Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
#         'Swimming Pool', '"Kids Play Areas"', 'Parking', 'Area (Sq.Ft.)',
#         'State', 'Area Type', 'Number of Bathrooms', 'Kids Play Areas'],
#        dtype='object'),
#  Index(['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
#         'Number of Rooms', 'Number of Bathroom', 'Area (Sq.Ft.)', 'Balcony',
#         'Clubhouse', 'Swimming Pool', 'Kids Play Areas', 'Parking', 'Area Type',
#         'State'],
#        dtype='object'))

# %%
column_order = ['City', 'Locality', 'Property Type', 'Price', 'Furnishing Status',
                'Number of Rooms', 'Number of Bathroom', 'Balcony', 'Clubhouse',
                'Swimming Pool', 'Kids Play Areas', 'Parking', 'Area (Sq.Ft.)',
                'State', 'Area Type']

# Reorder the columns of df2
df18 = df18[column_order]

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Karnatka', 'Chandigarh', 'Tamil Nadu', 'Delhi',
#        'Unknown', 'Telangana', 'Rajasthan', 'West Bengal',
#        'Uttar Pradesh', 'Maharashtra', 'Bihar'], dtype=object)

# %%
df = pd.concat([df, df18], ignore_index=True)

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Karnatka', 'Chandigarh', 'Tamil Nadu', 'Delhi',
#        'Unknown', 'Telangana', 'Rajasthan', 'West Bengal',
#        'Uttar Pradesh', 'Maharashtra', 'Bihar', 'Andhra Pradesh'],
#       dtype=object)

# %%
df
# Out:
#              City        Locality Property Type       Price Furnishing Status  \
# 0       Ahmedabad         Makarba   Residential  11500000.0         Furnished
# 1       Ahmedabad         Makarba   Residential   6500000.0       Unfurnished
# 2       Ahmedabad      Ambli Road   Residential  72100000.0    Semi-Furnished
# 3       Ahmedabad           Shela   Residential  13000000.0       Unfurnished
# 4       Ahmedabad        Bodakdev   Residential  15000000.0         Furnished
# ...           ...             ...           ...         ...               ...
# 52442  Vijayawada        Patamata   Residential  14900000.0    Semi-Furnished
# 52443  Vijayawada  Mutyalammapadu   Residential   9411599.0    Semi-Furnished
# 52444  Vijayawada     Kesarapalli   Residential   7500000.0         Furnished
# 52445  Vijayawada     Kesarapalli   Residential   4499000.0       Unfurnished
# 52446  Vijayawada          Kanuru   Residential   5400000.0       Unfurnished
#
# ...

# %%
s = df['State'].unique()
s
# Out:
# array(['Gujarat', 'Karnatka', 'Chandigarh', 'Tamil Nadu', 'Delhi',
#        'Unknown', 'Telangana', 'Rajasthan', 'West Bengal',
#        'Uttar Pradesh', 'Maharashtra', 'Bihar', 'Andhra Pradesh'],
#       dtype=object)

# %%
df
# Out:
#              City        Locality Property Type       Price Furnishing Status  \
# 0       Ahmedabad         Makarba   Residential  11500000.0         Furnished
# 1       Ahmedabad         Makarba   Residential   6500000.0       Unfurnished
# 2       Ahmedabad      Ambli Road   Residential  72100000.0    Semi-Furnished
# 3       Ahmedabad           Shela   Residential  13000000.0       Unfurnished
# 4       Ahmedabad        Bodakdev   Residential  15000000.0         Furnished
# ...           ...             ...           ...         ...               ...
# 52442  Vijayawada        Patamata   Residential  14900000.0    Semi-Furnished
# 52443  Vijayawada  Mutyalammapadu   Residential   9411599.0    Semi-Furnished
# 52444  Vijayawada     Kesarapalli   Residential   7500000.0         Furnished
# 52445  Vijayawada     Kesarapalli   Residential   4499000.0       Unfurnished
# 52446  Vijayawada          Kanuru   Residential   5400000.0       Unfurnished
#
# ...

# %%
duplicates = df[df.duplicated()]

# %%
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
# Number of duplicate rows: 20347

# %%
real_estate_cleaned = df.drop_duplicates()

# %%
real_estate_cleaned
# Out:
#              City        Locality Property Type       Price Furnishing Status  \
# 0       Ahmedabad         Makarba   Residential  11500000.0         Furnished
# 1       Ahmedabad         Makarba   Residential   6500000.0       Unfurnished
# 2       Ahmedabad      Ambli Road   Residential  72100000.0    Semi-Furnished
# 3       Ahmedabad           Shela   Residential  13000000.0       Unfurnished
# 4       Ahmedabad        Bodakdev   Residential  15000000.0         Furnished
# ...           ...             ...           ...         ...               ...
# 52442  Vijayawada        Patamata   Residential  14900000.0    Semi-Furnished
# 52443  Vijayawada  Mutyalammapadu   Residential   9411599.0    Semi-Furnished
# 52444  Vijayawada     Kesarapalli   Residential   7500000.0         Furnished
# 52445  Vijayawada     Kesarapalli   Residential   4499000.0       Unfurnished
# 52446  Vijayawada          Kanuru   Residential   5400000.0       Unfurnished
#
# ...

# %%
real_estate_cleaned.to_csv('real_estate_cleaned.csv', index=False)
